# %% [markdown]
# # BIKE RENTAL PYTHON PROJECT

# %%
import os # To intearct with local system directory // intearct with operating system
import pandas as pd # To process data, CSV I/O (read write csv etc) // data structures and data analysis tools
import numpy as np # Algebric operation (Linear algebra) // array-processing library

# Plots
import matplotlib.pyplot as plt # Matplotlib - 2D graphs and plots by python scripts // pyplot provides features to control line styles, font properties, formatting axes etc.
import seaborn as sns # For Plots // data visualization library based on matplotlib // high-level interface for drawing attractive and informative statistical graphics.

# %%
os.getcwd()
# Out:
# 'C:\\Users\\AVISHEK\\Desktop\\edWisor\\Projects\\Bike rental'

# %%
os.chdir("C:/Users/AVISHEK/Desktop/edWisor/Projects/Bike rental")

os.getcwd()
# Out:
# 'C:\\Users\\AVISHEK\\Desktop\\edWisor\\Projects\\Bike rental'

# %%
print(os.listdir(os.getcwd()))
# Out:
# ['DataN0103.pdf', 'day.csv', 'project report.docx', 'sample-report.pdf', '~$oject report.docx']

# %%
df_bike = pd.read_csv("day.csv")

# %%
print(df_bike.shape)

print(df_bike.head())

print(df_bike.dtypes)
#print(df_bike.info())
print(df_bike.describe())
# Out:
# (731, 16)
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600
# ...

# %%
########################################- UNIVARIATE ANALYSIS -################################################

# %%
print(df_bike['cnt'].describe())

# Distribution of target variable - Distribution Plot

sns.distplot(df_bike['cnt'])
# Out:
# count     731.000000
# mean     4504.348837
# std      1937.211452
# min        22.000000
# 25%      3152.000000
# 50%      4548.000000
# 75%      5956.000000
# max      8714.000000
# Name: cnt, dtype: float64
# C:\Users\AVISHEK\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Checking for distribution of independent numerical variable (Normal or not)

# %%
sns.distplot(df_bike['temp']); #'temp'is normal or not
# Out:
# C:\Users\AVISHEK\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(df_bike['atemp']); #'atemp'is normal or not
# Out:
# C:\Users\AVISHEK\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(df_bike['hum']); #'hum'is normal or not
# Out:
# C:\Users\AVISHEK\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(df_bike['windspeed']); #'windspeed'is normal or not
# Out:
# C:\Users\AVISHEK\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(df_bike['casual']); #'casual'is normal or not
# Out:
# C:\Users\AVISHEK\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(df_bike['registered']); #'registered'is normal or not
# Out:
# C:\Users\AVISHEK\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
print("Skewness : %f" % df_bike['cnt'].skew())
print("Kurtosis : %f" % df_bike['cnt'].kurt())
# Out:
# Skewness : -0.047353
# Kurtosis : -0.811922

# %%
pd.plotting.scatter_matrix(df_bike,figsize=(16,16))
plt.show()

# %%
# Checking relationship of numerical variable with Pair plots

bike_numeric = df_bike.loc[:,['temp','atemp','hum','windspeed','casual','registered','cnt']]

sns.set()
col = ['temp','atemp','hum','windspeed','casual','registered','cnt']
sns.pairplot(bike_numeric[col], height = 3 , kind = "reg")
plt.show()
# Out:
# C:\Users\AVISHEK\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.set_style("whitegrid")
sns.catplot(data=df_bike,x='season',kind='count',height=4,aspect=2)
sns.catplot(data=df_bike,x='yr',kind='count',height=4,aspect=2)
sns.catplot(data=df_bike,x='mnth',kind='count',height=4,aspect=2)
sns.catplot(data=df_bike,x='holiday',kind='count',height=4,aspect=2)
sns.catplot(data=df_bike,x='weekday',kind='count',height=4,aspect=2)
sns.catplot(data=df_bike,x='workingday',kind='count',height=4,aspect=2)
sns.catplot(data=df_bike,x='weathersit',kind='count',height=4,aspect=2)

# %%
sns.boxplot(data=df_bike[['season','yr','mnth','holiday','weekday','workingday','weathersit']])
fig=plt.gcf()
fig.set_size_inches(8,8)

# %%
########################################- OUTLIER ANALYSIS -###########################################

# The catagorical variables are free of outliers
# The numerical variables present are temp,atemp,hum,windspeed,casual,registered
# Out of the six numnerical variables temp,atemp,hum,windspeed are normalized variables hence no outliers
# casual and registered should be checked for outliers

# %%
#casual

df_bike.head()
sns.boxplot(data = df_bike[['casual']], orient = 'h')

# %%
plt.scatter(x=df_bike['casual'],y=df_bike['cnt'])
plt.xlabel("Casual")
plt.ylabel("Cnt")
plt.show()

# casual variable seems to have outliers which shoukd be delt with

# %%
#registered

df_bike.head()
sns.boxplot(data = df_bike[['registered']], orient = 'h')

# %%
plt.scatter(x=df_bike['registered'],y=df_bike['cnt'])
plt.xlabel("registered")
plt.ylabel("Cnt")
plt.show()

# The registered variable seems to have permissible outliers/no outliers

# %%
##########################################- MISSING VALUE ANALYSIS -############################################

missing_val = pd.DataFrame(df_bike.isnull().sum())
print(missing_val)
# Out:
#             0
# instant     0
# dteday      0
# season      0
# yr          0
# mnth        0
# holiday     0
# weekday     0
# workingday  0
# weathersit  0
# temp        0
# atemp       0
# hum         0
# windspeed   0
# casual      0
# registered  0
# cnt         0

# %%
###########################################- FEATURE SELECTION -#############################################

#draw  correlation matrix between all  numeric variables and analyse  what are the variables are important

bike_numeric.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_4b1344ee_6984_11e9_9d5b_38eaa7d9b4c6row0_col0 {
#             background-color:  #b40426;
#         }    #T_4b1344ee_6984_11e9_9d5b_38eaa7d9b4c6row0_col1 {
#             background-color:  #b50927;
#         }    #T_4b1344ee_6984_11e9_9d5b_38eaa7d9b4c6row0_col2 {
#             background-color:  #8badfd;
#         }    #T_4b1344ee_6984_11e9_9d5b_38eaa7d9b4c6row0_col3 {
#             background-color:  #3b4cc0;
#         }    #T_4b1344ee_6984_11e9_9d5b_38eaa7d9b4c6row0_col4 {
#             background-color:  #f2c9b4;
#         }    #T_4b1344ee_6984_11e9_9d5b_38eaa7d9b4c6row0_col5 {
#             background-color:  #f2cab5;
#         }    #T_4b1344ee_6984_11e9_9d5b_38eaa7d9b4c6row0_col6 {
#             background-color:  #f7b497;
#         }    #T_4b1344ee_6984_11e9_9d5b_38eaa7d9b4c6row1_col0 {
#             background-color:  #b50927;
#         }    #T_4b1344ee_6984_11e9_9d5b_38eaa7d9b4c6row1_col1 {
#             background-color:  #b40426;
# ...

# %%
############################################- FEATURE SCALING -##############################################
# Numerical variables except 'casual'and'registered' are normally distributed (distribution lies between 0 to 1)
#NORMALCY CHECK

colname=['casual','registered']

for i in colname :
    print(i);
    df_bike[i] = (df_bike[i]- min(df_bike[i]))/(max(df_bike[i])-min(df_bike[i]));
    
df_bike.head()
# Out:
# casual
# registered
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed    casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446  0.096538    0.091539
# 1           2  0.363478  0.353739  0.696087   0.248539  0.037852    0.093849
# 2           1  0.196364  0.189405  0.437273   0.248309  0.034624    0.174560
# 3           1  0.200000  0.212122  0.590435   0.160296  0.031103    0.207046
# 4           1  0.226957  0.229270  0.436957   0.186900  0.023474    0.216286
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# ...

# %%
#########################################- MODELING -##############################################
from sklearn.model_selection import train_test_split
df_bike2=df_bike.copy()
df_bike2.drop(columns=['atemp','hum'])
train,test = train_test_split(df_bike2 , test_size=0.2 , random_state = 125)

# %%
## DECISION TREE

 # MAPE : 14.65%
 # ACCURACY : 85.35%

from sklearn.tree import DecisionTreeRegressor
dt_model = DecisionTreeRegressor(random_state = 125).fit(train.iloc[:,2:11],train.iloc[:,11])
dt_predict = dt_model.predict(test.iloc[:,2:11])

# %%
# Calculate MAPE - Mean Absolute Percentage Error
def MAPE(y_true,y_pred):
    mape=np.mean(np.abs((y_true-y_pred)/y_true))*100
    return mape
MAPE(test.iloc[:,11],dt_predict)
# Out:
# 14.647619522697441

# %%
## RANDOM FOREST

 # MAPE : 12.70%
 # ACCURACY : 87.30%

from sklearn.ensemble import RandomForestRegressor
rf_model = RandomForestRegressor(n_estimators = 500 , random_state = 125).fit(train.iloc[:,2:11],train.iloc[:,11])
rf_predict = rf_model.predict(test.iloc[:,2:11])
MAPE(test.iloc[:,11],rf_predict)
# Out:
# 12.695823684385502

# %%
## LINEAR REGRESSION

 # MAPE : 16.34%
 # ACCURACY : 83.66%

import statsmodels.api as sm
lr_model = sm.OLS(train.iloc[:,11],train.iloc[:,2:11]).fit()
lr_predict = lr_model.predict(test.iloc[:,2:11])
MAPE(test.iloc[:,11],lr_predict)
# Out:
# 16.340926818166686
